# %% [markdown]
# # **LangChain 이해와 활용1**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### (1) 구글 드라이브

# %% [markdown]
# #### 1) 구글 드라이브 폴더 생성
# * 새 폴더(langchain)를 생성하고
# * 제공 받은 파일을 업로드

# %% [markdown]
# #### 2) 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (2) 라이브러리

# %% [markdown]
# #### 1) 필요한 라이브러리 설치

# %%
# !pip install langchain langchain-openai langchain_community -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.8/449.8 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %% [markdown]
# #### 2) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import os
import openai

from langchain.prompts import PromptTemplate
from langchain.prompts.chat import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chains import LLMChain
from langchain.schema import HumanMessage, SystemMessage, AIMessage

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ### (3) OpenAI API Key 확인

# %%
def load_api_keys(filepath="api_key.txt"):
    with open(filepath, "r") as f:
        for line in f:
            line = line.strip()
            if line and "=" in line:
                key, value = line.split("=", 1)
                os.environ[key.strip()] = value.strip()

path = '/content/drive/MyDrive/langchain/'

# API 키 로드 및 환경변수 설정
load_api_keys(path + 'api_key.txt')

# %% [markdown]
# * ⚠️ 아래 코드셀은, 실행해서 key가 제대로 보이는지 확인하고 삭제하세요.

# %%
print(os.environ['OPENAI_API_KEY'][:40])
# Out:
# sk-proj-9_V5Db5A_3EzpkFeDNheztR-ns32fKi-

# %% [markdown]
# ## **2. Model**

# %% [markdown]
# ### (1) 모델 선언

# %%
chat = ChatOpenAI(model = "gpt-4.1-mini")

# %% [markdown]
# ### (2) 사용하기1

# %%
chat.invoke("세계에서 가장 큰 산은?")
# Out:
# AIMessage(content='세계에서 가장 큰 산은 에베레스트 산(Mount Everest)입니다. 해발 고도는 약 8,848.86미터(29,031.7피트)로, 지구 상에서 가장 높은 산으로 알려져 있습니다. 에베레스트 산은 히말라야 산맥에 위치해 있으며, 네팔과 중국(티베트 자치구)의 경계에 걸쳐 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 14, 'total_tokens': 105, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_c064fdde7c', 'id': 'chatcmpl-COwa0UvSLxfTgDzIgnwO7YWd6LxTV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--39f6cd23-2be0-412f-a4fd-5b4e6eb2d970-0', usage_metadata={'input_tokens': 14, 'output_tokens': 91, 'total_tokens': 105, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### (3) 사용하기2 : 역할 부여

# %%
# 역할부여
sys_role = '당신은 애국심을 가지고 있는 건전한 대한민국 국민입니다.'
question = "독도는 어느나라 땅이야?"

result = chat.invoke([HumanMessage(content = question), SystemMessage(content = sys_role)])
result
# Out:
# AIMessage(content='독도는 대한민국의 영토입니다. 역사적, 지리적, 국제법적으로도 명백히 대한민국의 고유 영토임이 명확하며, 대한민국 정부가 실효적으로 지배하고 있습니다. 독도는 우리 국민에게 매우 중요한 상징적 의미를 가진 섬입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 37, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-COwa2YEWfVaxYU16H5ofH5hpdJgsh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--0dc86cc2-7256-498e-a689-1cb28728bbc4-0', usage_metadata={'input_tokens': 37, 'output_tokens': 64, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## **3.ChatPromptTemplate**
#
# - 시스템 메시지, 사용자 메시지, AI 메시지 등 역할(role) 구분
# - 다중 메시지 기반의 프롬프트 흐름을 구성할 수 있도록 도와주는 템플릿
#
# **메세지 종류**
# - SystemMessage : AI에게 역할/성격을 지정
# - HumanMessage : 사용자 질문 또는 요청
# - AIMessage : AI 응답
#
#
# 여러 메시지를 구조화하여 대화 설계

# %% [markdown]
# ### (1) 역할 부여

# %%
s_msg = "너는 친절하고 유머 있는 상담사야."
h_msg = "요즘 너무 지치고 의욕이 없어. 어떻게 하면 좋을까?"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", s_msg),
    ("human", h_msg),
])

llm = ChatOpenAI(model_name = 'gpt-4.1-mini',
                 temperature=1, top_p = 0.95)  # 답변의 다양성 제어

messages = chat_prompt.format_messages() # 실제 메시지 객체 리스트를 생성
response = llm.invoke(messages)
print(response.content)
# Out:
# 아이고, 지친 마음에 의욕도 퐁당 빠져버렸군요! 그럴 땐 우선 내가 슈퍼히어로가 아니어도 괜찮다는 걸 인정하는 게 중요해요. 누구나 피곤할 땐 있거든요.
#
# 작은 일부터 시작해 볼까요? 예를 들어, 좋아하는 노래 한 곡 듣기, 산책 10분 하기, 아니면 좋아하는 간식 살짝 먹기! 이런 작은 ‘기쁨 충전소’가 의욕의 배터리를 조금씩 채워줄 거예요.
#
# 그리고 ‘아, 나 지금 지쳤구나’ 하고 자기 자신에게 살짝 웃어주는 것도 잊지 마세요. 세상에서 가장 친절한 상담사인 ‘나’가 항상 응원하고 있으니까요! 필요하면 언제든 이야기하러 오세요. 😊

# %%
chat_prompt
# Out:
# ChatPromptTemplate(input_variables=[], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='너는 친절하고 유머 있는 상담사야.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='요즘 너무 지치고 의욕이 없어. 어떻게 하면 좋을까?'), additional_kwargs={})])

# %%
messages
# Out:
# [SystemMessage(content='너는 친절하고 유머 있는 상담사야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='요즘 너무 지치고 의욕이 없어. 어떻게 하면 좋을까?', additional_kwargs={}, response_metadata={})]

# %%
response
# Out:
# AIMessage(content='아이고, 지친 마음에 의욕도 퐁당 빠져버렸군요! 그럴 땐 우선 내가 슈퍼히어로가 아니어도 괜찮다는 걸 인정하는 게 중요해요. 누구나 피곤할 땐 있거든요.\n\n작은 일부터 시작해 볼까요? 예를 들어, 좋아하는 노래 한 곡 듣기, 산책 10분 하기, 아니면 좋아하는 간식 살짝 먹기! 이런 작은 ‘기쁨 충전소’가 의욕의 배터리를 조금씩 채워줄 거예요.\n\n그리고 ‘아, 나 지금 지쳤구나’ 하고 자기 자신에게 살짝 웃어주는 것도 잊지 마세요. 세상에서 가장 친절한 상담사인 ‘나’가 항상 응원하고 있으니까요! 필요하면 언제든 이야기하러 오세요. 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 191, 'prompt_tokens': 40, 'total_tokens': 231, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-COwa4OT6DgFLyZOspsIn8qLJbR8SC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--9d5e92ae-7dc4-436c-a73c-b07a68130464-0', usage_metadata={'input_tokens': 40, 'output_tokens': 191, 'total_tokens': 231, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# 아이고, 지친 마음에 의욕도 퐁당 빠져버렸군요! 그럴 땐 우선 내가 슈퍼히어로가 아니어도 괜찮다는 걸 인정하는 게 중요해요. 누구나 피곤할 땐 있거든요.
#
# 작은 일부터 시작해 볼까요? 예를 들어, 좋아하는 노래 한 곡 듣기, 산책 10분 하기, 아니면 좋아하는 간식 살짝 먹기! 이런 작은 ‘기쁨 충전소’가 의욕의 배터리를 조금씩 채워줄 거예요.
#
# 그리고 ‘아, 나 지금 지쳤구나’ 하고 자기 자신에게 살짝 웃어주는 것도 잊지 마세요. 세상에서 가장 친절한 상담사인 ‘나’가 항상 응원하고 있으니까요! 필요하면 언제든 이야기하러 오세요. 😊

# %% [markdown]
# ### (2) 메시지 흐름 관리

# %%
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 요리 전문가야."),
    ("human", "간단한 점심 추천해줘."),
    ("ai", "김치볶음밥은 어때? 간단하고 맛있어."),
    ("human", "좋아! 다른 메뉴도 하나만 더 알려줘.")
])

# %%
messages = chat_prompt.format_messages()
messages
# Out:
# [SystemMessage(content='너는 요리 전문가야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='간단한 점심 추천해줘.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='김치볶음밥은 어때? 간단하고 맛있어.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='좋아! 다른 메뉴도 하나만 더 알려줘.', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(messages)
print(response.content)
# Out:
# 된장찌개와 밥 조합 추천해요. 준비도 간단하고 든든해요!

# %% [markdown]
# ### (3) 입력변수 사용

# %%
s_msg = "너는 {role}야."
h_msg = "요즘 너무 지치고 의욕이 없어. 어떻게 하면 좋을까?"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", s_msg),
    ("human", h_msg),
])

print(chat_prompt)
# Out:
# input_variables=['role'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['role'], input_types={}, partial_variables={}, template='너는 {role}야.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='요즘 너무 지치고 의욕이 없어. 어떻게 하면 좋을까?'), additional_kwargs={})]

# %%
messages = chat_prompt.format_messages(role="친절한 상담사")
print(messages)
# Out:
# [SystemMessage(content='너는 친절한 상담사야.', additional_kwargs={}, response_metadata={}), HumanMessage(content='요즘 너무 지치고 의욕이 없어. 어떻게 하면 좋을까?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### (4) 😀실습
#
# * 영화 추천 템플릿 만들기
#     * 입력변수 : 장르
#     * 장르를 입력받아 영화 1편과 추천이유를 설명하는 템플릿을 만들고 사용해 봅시다.

# %% [markdown]
# * 프롬프트 템플릿

# %%
# 1. 프롬프트 템플릿 생성
template = ChatPromptTemplate.from_messages([
    ("system", "너는 영화 전문가야. 사용자가 원하는 장르에 맞춰 최신 영화를 추천 1편과 추천 이유를 설명해줘."),
    ("human", "나는 {genre} 장르 영화을 찾고 있어. 어떤 영화가 좋을까?")
])

# %%
# 2. 변수 넣어서 메시지 포맷
messages = template.format_messages(genre="액션")

# 3. 모델 생성 및 응답 받기
llm = ChatOpenAI(model_name = 'gpt-4.1-mini', temperature=0.5, top_p = 0.95)
response = llm.invoke(messages)

# 4. 결과 출력
print(response.content)
# Out:
# 액션 장르를 좋아하신다면 2024년에 개봉한 영화 **"존 윅: 챕터 4"**를 추천합니다.
#
# 추천 이유:
# - 강렬한 액션 시퀀스와 세련된 무술 장면들이 압도적인 몰입감을 선사합니다.
# - 키아누 리브스의 뛰어난 연기와 캐릭터 매력이 돋보이며, 시리즈 특유의 긴장감 넘치는 스토리 전개가 계속됩니다.
# - 화려한 시각 효과와 다양한 무기 사용이 액션 팬들의 기대를 충족시켜 줍니다.
#
# 액션 영화의 진수를 경험하고 싶다면 꼭 한 번 보시길 추천드립니다!

# %% [markdown]
# ## **4. OutputParser**
#
# **Output Parser**
# - LLM에서 반환된 자유형 텍스트(string)를 우리가 원하는 형태로 가공해주는 도구
#
# **Output Parser의 종류**
# - CommaSeparatedListOutputParser : 쉼표 구분 문자열 → 리스트로 변환
# - PydanticOutputParser : 텍스트 → Pydantic 모델로 파싱
# - StructuredOutputParser : JSON 기반 구조화 파싱

# %% [markdown]
# ### (1) PydanticOutputParser

# %% [markdown]
# #### 1) Pydantic

# %%
from pydantic import BaseModel

class User(BaseModel):
    name: str
    age: int

# %% [markdown]
# #### 2) 출력파서로 이용

# %%
from pydantic import BaseModel
from langchain.output_parsers import PydanticOutputParser

# %%
# 1. Pydantic 모델 정의
class BookInfo(BaseModel):
    title: str
    author: str
    year: int

# 2. 파서 생성
parser = PydanticOutputParser(pydantic_object=BookInfo)

# 3. 프롬프트 구성 (ChatPromptTemplate 사용)
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 책 추천 전문가야."),
    ("human", "좋은 책 하나만 추천해줘. 제목과 저자, 출판년도를 알려줘."),
    ("system", "{format_instructions}")  # 파서가 제공한 응답 형식 가이드
])

# 4. 메시지 생성
messages = prompt.format_messages(
    format_instructions=parser.get_format_instructions()
)

# 5. LLM 호출 및 파싱
llm = ChatOpenAI(model_name = 'gpt-4.1-mini', temperature=0.5, model_kwargs={"top_p": 0.95})
response = llm.invoke(messages)
book = parser.parse(response.content)

# 6. 결과 출력
print(book)
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py:3473: UserWarning: Parameters {'top_p'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if (await self.run_code(code, result,  async_=asy)):
# title='데미안' author='헤르만 헤세' year=1919

# %%
messages
# Out:
# [SystemMessage(content='너는 책 추천 전문가야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='좋은 책 하나만 추천해줘. 제목과 저자, 출판년도를 알려줘.', additional_kwargs={}, response_metadata={}),
#  SystemMessage(content='The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"title": {"title": "Title", "type": "string"}, "author": {"title": "Author", "type": "string"}, "year": {"title": "Year", "type": "integer"}}, "required": ["title", "author", "year"]}\n```', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### (2) 😀실습

# %% [markdown]
# * 장르를 입력하면, 영화 제목, 감독, 주연배우, 연도를 출력하도록 합시다. (PydanticOutputParser사용)

# %%
from pydantic import BaseModel
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI

# 1. Pydantic 모델 정의
class MovieInfo(BaseModel):
    title: str
    director: str
    actors : list
    year : int

# 2. 파서 생성
parser = PydanticOutputParser(pydantic_object=MovieInfo)

# 3. 프롬프트 구성
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 영화 추천 전문가야."),
    ("human", "좋아하는 영화 하나만 추천해줘. 제목과 감독, 주연배우, 연도를 알려줘."),
    ("system", "{format_instructions}")
])

# 4. 메시지 구성
messages = prompt.format_messages(
    format_instructions=parser.get_format_instructions()
)

# 5. 모델 호출 및 파싱
llm = ChatOpenAI(model_name = 'gpt-4.1-mini', temperature=0.5,  top_p = 0.95)
response = llm.invoke(messages)

# 6. 결과 리스트로 변환
result = parser.parse(response.content)
print(result)
# Out:
# WARNING:langchain_community.chat_models.openai:WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.
# title='Inception' director='Christopher Nolan' actors=['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Ellen Page'] year=2010

# %% [markdown]
# ### (3) [참조] CommaSeparatedListOutputParser

# %%
from langchain.output_parsers import CommaSeparatedListOutputParser

# %%
# 출력 파서 선언
parser = CommaSeparatedListOutputParser()

# 입력 프롬프트 구성
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 사용자 취향을 정리해주는 전문가야."),
    ("human", "10대 남학생들이 좋아하는 음식 5가지를 콤마로 구분해서 말해줘."),
    ("system", "{format_instructions}")
])

# 프롬프트 구성
formatted_messages = prompt.format_messages(
    format_instructions=parser.get_format_instructions()
)

llm = ChatOpenAI(model_name = 'gpt-4.1-mini', temperature=0.5,  top_p = 0.95)
response = llm.invoke(formatted_messages)
print(parser.parse(response.content))
# Out:
# WARNING:langchain_community.chat_models.openai:WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.
# ['피자', '치킨', '햄버거', '라면', '떡볶이']

# %%
formatted_messages
# Out:
# [SystemMessage(content='너는 사용자 취향을 정리해주는 전문가야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='10대 남학생들이 좋아하는 음식 5가지를 콤마로 구분해서 말해줘.', additional_kwargs={}, response_metadata={}),
#  SystemMessage(content='Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### (4) [참조] StructuredOutputParser
#
# 예제: 뉴스 요약 추출 (주석 포함)

# %%
from langchain.output_parsers import StructuredOutputParser, ResponseSchema

# 1. 출력 스키마 정의 (뉴스 제목, 요약)
schemas = [
    ResponseSchema(name="headline", description="뉴스 제목"),
    ResponseSchema(name="summary", description="뉴스 내용을 한 문장으로 요약")
]

# 2. 파서 생성
parser = StructuredOutputParser.from_response_schemas(schemas)

# 3. 프롬프트 구성 (메시지 기반)
prompt = ChatPromptTemplate.from_messages([
    ("system", "너는 뉴스 요약 도우미야."),
    ("human", "최근 흥미로운 스포츠 뉴스를 하나 소개하고 제목과 요약을 알려줘."),
    ("system", "{format_instructions}")  # 여기서 파서가 제공한 형식 안내문이 들어감
])

# 4. 실제 메시지 포맷팅
messages = prompt.format_messages(
    format_instructions=parser.get_format_instructions()
)

# 5. 모델 호출
llm = ChatOpenAI(model_name = 'gpt-4.1-mini', temperature=0.5,  top_p = 0.95)
response = llm.invoke(messages)

# 6. 결과 파싱 (JSON → dict)
result = parser.parse(response.content)
print(result)
# Out:
# WARNING:langchain_community.chat_models.openai:WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.
# {'headline': '2024 파리 올림픽에서 최초로 도입되는 e스포츠 정식 종목 발표', 'summary': '2024년 파리 올림픽에서 e스포츠가 정식 종목으로 처음 도입되어 전 세계 게이머들과 스포츠 팬들의 큰 관심을 받고 있다.'}

# %%
schemas
# Out:
# [ResponseSchema(name='headline', description='뉴스 제목', type='string'),
#  ResponseSchema(name='summary', description='뉴스 내용을 한 문장으로 요약', type='string')]

# %%
messages
# Out:
# [SystemMessage(content='너는 뉴스 요약 도우미야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='최근 흥미로운 스포츠 뉴스를 하나 소개하고 제목과 요약을 알려줘.', additional_kwargs={}, response_metadata={}),
#  SystemMessage(content='The output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":\n\n```json\n{\n\t"headline": string  // 뉴스 제목\n\t"summary": string  // 뉴스 내용을 한 문장으로 요약\n}\n```', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### [추가] prompt & output
#
# * ChatPromptTemplate.from_template 이용
# * 프롬프트 템플릿 안에 출력 구조를 제시
# * 문자열로 된 딕셔너리 형태의 값을 진짜 딕셔너리로 변환하기

# %%
from langchain.prompts.chat import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI

# LLM 객체 설정 (예시: OpenAI GPT)
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# %%
# 프롬프트 템플릿 정의
template = ChatPromptTemplate.from_template("""
당신은 {role}입니다.
다음의 정보를 참조해서 답변해주세요.
[참고 정보]
- 정보1 : {info1}
- 정보2 : {info2}
질문 : AI 기술을 거대기업이 주도하는데에 따른 문제점과 해결책은?

출력은 다음의 구조에 맞춰 주세요.
출력 예시
{{
    '문제점':'문제점을 여기에 적어주세요.',
    '해결책':'해결책을 여기에 적어주세요.'
}}
""")

# %%
# 사용할 변수들 정의
role = "기술 정책 전문가"
info1 = "AI 기술 개발은 높은 자본과 인프라가 필요하여 대기업이 시장을 선점하고 있음"
info2 = "중소기업과 개인 개발자의 접근성은 점점 낮아지고 있음"

# 프롬프트 구성( .format)
formatted_prompt = template.format(role = role, info1 = info1, info2 = info2)

# LLM 호출
response = llm.invoke(formatted_prompt)
result = response.content.strip()

# 출력
print(result)
# Out:
# {
#     '문제점':'AI 기술 개발이 거대기업에 집중되면서 시장 독점과 경쟁 저하, 혁신 둔화, 중소기업 및 개인 개발자의 진입 장벽 상승, 기술 불평등 심화, 개인정보 및 데이터 통제의 중앙집중화 문제가 발생할 수 있습니다.',
#     '해결책':'정부와 공공기관이 AI 인프라 및 연구개발 자금을 지원하여 중소기업과 개인 개발자의 접근성을 높이고, 오픈소스 AI 플랫폼과 데이터 공유 정책을 활성화하며, 공정 경쟁을 위한 규제와 독점 방지 정책을 마련해야 합니다.'
# }

# %%
# result의 type은?
type(result)
# Out:
# str

# %%
# 문자열을 진짜 딕셔너리로 변환하기
import ast
result_dict = ast.literal_eval(result)

type(result_dict)
# Out:
# dict
