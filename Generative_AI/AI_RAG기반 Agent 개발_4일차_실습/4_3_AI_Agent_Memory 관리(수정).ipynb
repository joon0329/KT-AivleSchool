# %% [markdown]
# # **AI Agent_Memory 관리**
#
# **Memory**
# - AI Agent가 이전 상태(state)나 대화 기록을 유지하고 재사용할 수 있도록 하는 기능
#     - 유저와 AI 간의 대화를 저장하여 지속적인 맥락을 유지
#     - 단순한 세션 메모리 뿐만 아니라, 외부 저장소를 활용하여 장기적인 상태를 저장
# - 단기기억과 장기기억 정보를 제어하기 위한 로직을 넣을 수 있음.

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### (1) 구글 드라이브

# %% [markdown]
# #### 1) 구글 드라이브 폴더 생성
# * 새 폴더(LangGraph)를 생성하고
# * 제공 받은 파일을 업로드

# %% [markdown]
# #### 2) 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### (2) 라이브러리

# %% [markdown]
# #### 1) 필요한 라이브러리 설치

# %%
# !pip install langchain langgraph typing typing_extensions langchain-openai langchain_core langchain-community wikipedia -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 4.3 MB/s eta 0:00:00
#   Building wheel for typing (setup.py) ... done
#   Building wheel for wikipedia (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %% [markdown]
# #### 2) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import os
import openai

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from typing import Annotated, Literal, TypedDict
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_core.tools import tool
from langgraph.graph import END, START, StateGraph, MessagesState, add_messages
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import ToolNode

# %% [markdown]
# ### (3) OpenAI API Key 확인

# %%
def load_api_keys(filepath="api_key.txt"):
    with open(filepath, "r") as f:
        for line in f:
            line = line.strip()
            if line and "=" in line:
                key, value = line.split("=", 1)
                os.environ[key.strip()] = value.strip()

path = '/content/drive/MyDrive/langchain/'

# API 키 로드 및 환경변수 설정
load_api_keys(path + 'api_key.txt')

# %% [markdown]
# ⚠️ 아래 코드셀은, 실행해서 key가 제대로 보이는지 확인하고 삭제하세요.

# %%
print(os.environ['OPENAI_API_KEY'][:30])
# Out:
# sk-6HnpTor5FDdHd3WXGaRUshfzSdb

# %% [markdown]
# ## 2.기억력 없는 chatbot

# %% [markdown]
# ### (1) State 정의

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]

# %% [markdown]
# ### (2) Node 정의

# %%
llm = ChatOpenAI(model="gpt-4.1-mini")  # 언어 모델을 gpt-4.1-mini로 설정

def chatbot(state: State):
    return {"messages": [llm.invoke(state["messages"])]}

# %% [markdown]
# ### (3) 그래프 정의

# %%
# initiate a graph
builder = StateGraph(State)

# add a node
builder.add_node("chatbot", chatbot)

# connect nodes
builder.add_edge(START, "chatbot")
builder.add_edge("chatbot", END)

# compile the graph
graph = builder.compile()

# %% [markdown]
# * 그래프 시각화

# %%
from IPython.display import Image, display

# 외부 서버를 호출하는 동안 대기시간 초과로 오류가 날 수 있습니다.
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    pass

# %% [markdown]
# ### (4) Graph 실행

# %% [markdown]
# * 실행1

# %%
result = graph.invoke({"messages": [HumanMessage("안녕? 내 이름은 한기영이야.")]})
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 한기영이야.
# ================================== Ai Message ==================================
#
# 안녕하세요, 한기영님! 만나서 반가워요. 어떻게 도와드릴까요?

# %% [markdown]
# * 실행2

# %%
result = graph.invoke({"messages": [HumanMessage("내 이름이 뭐라고?")]})
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 한기영이야.
# ================================== Ai Message ==================================
#
# 안녕하세요, 한기영님! 만나서 반가워요. 어떻게 도와드릴까요?
# ================================ Human Message =================================
#
# 내 이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 한기영님이라고 하셨어요! 맞나요?

# %% [markdown]
# ### [추가] 메모리 없이 스레드만 추가하면?

# %%
t100 = {"configurable": {"thread_id": "100"}}

# %%
result = graph.invoke({"messages": [HumanMessage("안녕? 내 이름은 한기영이야.")]}, t100)
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 한기영이야.
# ================================== Ai Message ==================================
#
# 안녕하세요, 한기영님! 만나서 반갑습니다. 어떻게 도와드릴까요?

# %%
result = graph.invoke({"messages": [HumanMessage("내 이름이 뭐라고?")]}, t100)
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 내 이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 죄송하지만, 사용자의 이름을 알 수가 없어요. 이름을 알려주시면 기억하도록 할게요!

# %%
# initiate a graph
builder = StateGraph(State)

# add a node
builder.add_node("chatbot", chatbot)

# connect nodes
builder.add_edge(START, "chatbot")
builder.add_edge("chatbot", END)

# compile the graph
memory = MemorySaver()
graph = builder.compile(checkpointer = memory)

# %%
t200 = {"configurable": {"thread_id": "200"}}

# %%
result = graph.invoke({"messages": [HumanMessage("안녕? 내 이름은 한기영이야.")]}, t200)
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 한기영이야.
# ================================== Ai Message ==================================
#
# 안녕하세요, 한기영님! 만나서 반가워요. 어떻게 도와드릴까요?

# %%
result = graph.invoke({"messages": [HumanMessage("내 이름이 뭐라고?")]}, t200)
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 한기영이야.
# ================================== Ai Message ==================================
#
# 안녕하세요, 한기영님! 만나서 반가워요. 어떻게 도와드릴까요?
# ================================ Human Message =================================
#
# 내 이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 한기영님이라고 하셨어요! 맞나요?

# %% [markdown]
# ## 3.Agent에 메모리 추가
#
# **메모리 종류**
# - MemorySaver : Short-term Memory
# - SqliteSaver : Long-term Memory

# %% [markdown]
# ### (1) 메모리 준비 : MemorySaver
# **MemorySaver**
# - Short-term Memory
# - LangGraph에서 제공하는 체크포인트(Checkpoint) 저장소
# - 그래프 실행 중 생성되는 상태(state)를 자동으로 저장하고 필요 시 복원할 수 있게 해주는 메모리 기반 저장소
# - 특징
#
# ![image.png](data:image/png;base64,...)

# %%
# 체크포인터를 추가하여 그래프를 컴파일하면 메모리가 활성화됩니다.
from langgraph.checkpoint.memory import MemorySaver  # MemorySaver 모듈 가져오기
memory = MemorySaver()  # 메모리 기반 체크포인터 초기화

# %% [markdown]
# ### (2) 이전 그래프 다시 컴파일

# %%
# 체크포인터와 함께 그래프 컴파일
agent_with_memory = builder.compile(checkpointer=memory)

# %% [markdown]
# ### (3) 실행

# %% [markdown]
# * 스레드 지정

# %%
# 대화 흐름을 구분하기 위한 thread_id 설정
# 각 실행 흐름(예: 특정 대화 스레드)에 대해 고유한 thread_id를 키로 사용하고, 해당 키에 상태 데이터를 저장합니다.
thread_1 = {"configurable": {"thread_id": "1"}}

# %% [markdown]
# * 첫번째 메시지

# %%
messages = [HumanMessage(content="3과 4를 더하라")]
messages = agent_with_memory.invoke({"messages": messages}, thread_1)

for m in messages['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 3과 4를 더하라
# ================================== Ai Message ==================================
#
# 3과 4를 더하면 7입니다.

# %% [markdown]
# * 두번째 메시지

# %%
messages = [HumanMessage(content="거기에 2를 곱하라.")]
messages = agent_with_memory.invoke({"messages": messages}, thread_1)

for m in messages['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 3과 4를 더하라
# ================================== Ai Message ==================================
#
# 3과 4를 더하면 7입니다.
# ================================ Human Message =================================
#
# 거기에 2를 곱하라.
# ================================== Ai Message ==================================
#
# 7에 2를 곱하면 14입니다.

# %% [markdown]
# ### (4) 새로운 대화

# %% [markdown]
# * 새로운 thread id 부여

# %%
# 새로운 스레드 id 부여
thread_2 = {"configurable": {"thread_id": "2"}}

messages = [HumanMessage(content="금리에 대한 정의를 알려줘.")]
messages = agent_with_memory.invoke({"messages": messages}, thread_2)

for m in messages['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 금리에 대한 정의를 알려줘.
# ================================== Ai Message ==================================
#
# 금리(interest rate)는 일정 기간 동안 돈을 빌리거나 빌려줄 때 적용되는 비용 또는 수익의 비율을 말합니다. 쉽게 말해, 돈을 빌릴 때 지불해야 하는 대가 또는 돈을 예금할 때 받는 보상의 비율을 나타냅니다. 보통 연 단위 퍼센트(%)로 표현되며, 금리가 높을수록 돈을 빌리는 비용이 커지고, 예금자의 수익도 커집니다. 금리는 경제에 큰 영향을 미치며, 중앙은행의 정책금리, 대출금리, 예금금리 등 다양한 형태로 존재합니다.

# %% [markdown]
# * 이전 thread id로 다시 대화

# %%
# 첫 번째 입력 메시지를 정의
messages = [HumanMessage(content="마지막으로 계산했던 숫자가 뭐였지?")]

# 그래프 실행 (MemorySaver가 활성화된 그래프 사용)
messages = agent_with_memory.invoke({"messages": messages},thread_1)
# 결과 메시지를 출력
for m in messages['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 3과 4를 더하라
# ================================== Ai Message ==================================
#
# 3과 4를 더하면 7입니다.
# ================================ Human Message =================================
#
# 거기에 2를 곱하라.
# ================================== Ai Message ==================================
#
# 7에 2를 곱하면 14입니다.
# ================================ Human Message =================================
#
# 마지막으로 계산했던 숫자가 뭐였지?
# ================================== Ai Message ==================================
#
# 마지막으로 계산했던 숫자는 14입니다.

# %% [markdown]
# ### (5) 실습
# * 2번 파일의 실습1에 메모리를 추가해 봅시다.

# %% [markdown]
# * LLM을 하나 생성하시오 (ChatOpenAI)
# * 다음 도구 3개를 load_tools()를 사용하여 불러오고, ToolNode로 묶으시오
#     * llm-math, wikipedia, serpapi
# * GPT에게 도구 목록을 알려주기 위해 .bind_tools(tools)를 사용하시오
# * 이를 위해 필요한 준비작업을 수행하시오.
#     * serpapi api key를 받아 등록
#     * 필요한 라이브러리 설치

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt.tool_node import ToolNode
from langchain.agents import load_tools
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from typing import Literal, Annotated
from typing_extensions import TypedDict
from langchain_core.tools import tool

# %% [markdown]
# * 1) 메모리 준비 : MemorySaver

# %%
# 체크포인터를 추가하여 그래프를 컴파일하면 메모리가 활성화됩니다.
from langgraph.checkpoint.memory import MemorySaver  # MemorySaver 모듈 가져오기
memory = MemorySaver()  # 메모리 기반 체크포인터 초기화

# %% [markdown]
# * 2) Tool 준비하기

# %%
# !pip install google-search-results -q
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for google-search-results (setup.py) ... done

# %%
from langchain.agents import load_tools

llm = ChatOpenAI(model="gpt-4.1-mini")
tools = load_tools(["llm-math", "wikipedia", "serpapi"], llm=llm) # 일부 툴이 LLM을 내부적으로 쓸 때 필요한 설정

# %% [markdown]
# * 3) ToolNode 생성

# %%
tool_node = ToolNode(tools)

# 툴을 쓸 수 있는 LLM
llm_with_tools = llm.bind_tools(tools)  # GPT가 이 툴들을 사용하겠다고 판단할 수 있게 도와주는 설정

# %% [markdown]
# * 4) 그래프 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * State

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]

# %% [markdown]
# * Node 와 분기 함수(conditional edge를 위한 함수)

# %%
# 모델 호출 함수 (GPT 호출)
def call_model(state: State):
    messages = state["messages"]
    response = llm_with_tools.invoke(messages)
    return {"messages": [response]}

# 조건 분기 함수: 툴 호출이 필요한가?
def should_continue(state: State) -> Literal["tools", END]:  # 출력은 반드시 "tools" 혹은 END 여야 함.
    messages = state["messages"]
    last_message = messages[-1]  # 가장 최근 message
    if last_message.tool_calls:
        return "tools"
    return END

# %% [markdown]
# * 그래프 구성

# %%
builder = StateGraph(State)

# 노드 추가
builder.add_node("call_model", call_model)
builder.add_node("tools", tool_node)

# 연결
builder.set_entry_point("call_model")
builder.add_conditional_edges("call_model", should_continue)
builder.add_edge("tools", "call_model")  # 루프 연결

# 컴파일 : 메모리 포함
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# * 그래프 시각화

# %%
# 외부 서버를 호출하는 동안 대기시간 초과로 오류가 날 수 있습니다.
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    pass

# %% [markdown]
# * 5) 그래프 사용하기

# %%
# 대화 흐름을 구분하기 위한 thread_id 설정
# 각 실행 흐름(예: 특정 대화 스레드)에 대해 고유한 thread_id를 키로 사용하고, 해당 키에 상태 데이터를 저장합니다.
th_1 = {"configurable": {"thread_id": "1"}}

# %% [markdown]
# * 첫번째 메시지

# %%
result = graph.invoke({"messages": [HumanMessage(content="유로 2024 우승팀은?")]}, th_1)

# 출력
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 유로 2024 우승팀은?
# ================================== Ai Message ==================================
# Tool Calls:
#   Search (call_fqrybjC321BXMXnsjlMCPtCg)
#  Call ID: call_fqrybjC321BXMXnsjlMCPtCg
#   Args:
#     __arg1: Euro 2024 winner
# ================================= Tool Message =================================
# Name: Search
#
# Spain national football team
# ================================== Ai Message ==================================
#
# 유로 2024의 우승팀에 관한 최신 정보는 아직 확정되지 않았습니다. 대회가 진행 중이거나 예정되어 있을 수 있습니다. 정확한 결과가 나올 때까지 조금 더 기다려야 할 것 같습니다. 추가로 궁금한 점이 있으면 알려주세요!

# %% [markdown]
# * 두번째 메시지

# %%
result = graph.invoke({"messages": [HumanMessage(content="몇대 몇이었어?")]}, th_1)

# 출력
for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 유로 2024 우승팀은?
# ================================== Ai Message ==================================
# Tool Calls:
#   Search (call_fqrybjC321BXMXnsjlMCPtCg)
#  Call ID: call_fqrybjC321BXMXnsjlMCPtCg
#   Args:
#     __arg1: Euro 2024 winner
# ================================= Tool Message =================================
# Name: Search
#
# Spain national football team
# ================================== Ai Message ==================================
#
# 유로 2024의 우승팀에 관한 최신 정보는 아직 확정되지 않았습니다. 대회가 진행 중이거나 예정되어 있을 수 있습니다. 정확한 결과가 나올 때까지 조금 더 기다려야 할 것 같습니다. 추가로 궁금한 점이 있으면 알려주세요!
# ================================ Human Message =================================
#
# 몇대 몇이었어?
# ================================== Ai Message ==================================
#
# 유로 2024 결승전의 최종 점수에 대한 정보가 현재 없습니다. 대회가 아직 진행 중이거나 결과가 발표되지 않았을 수 있습니다. 특정 경기의 결과나 점수에 대해 더 알고 싶으시면, 알려주세요.

# %% [markdown]
# ## 4.메모리 다루기

# %% [markdown]
# ### (1) 메모리 조회

# %% [markdown]
# * thread id 1 에 저장된 메모리 스냅샷

# %%
agent_with_memory.get_state(thread_1).values
# Out:
# {'messages': [HumanMessage(content='3과 4를 더하라', additional_kwargs={}, response_metadata={}, id='fcd3d477-29f4-49c8-9652-3c687e50ab74'),
#   AIMessage(content='3과 4를 더하면 7입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 15, 'total_tokens': 26, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_c064fdde7c', 'id': 'chatcmpl-CP1H5a5QIyvU8CGwKnZVLBiWq3vFN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--d29e9525-41f8-49c5-96df-3ae530b188fd-0', usage_metadata={'input_tokens': 15, 'output_tokens': 11, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='거기에 2를 곱하라.', additional_kwargs={}, response_metadata={}, id='7da44329-bdec-4980-9ed6-84dd88c712e2'),
#   AIMessage(content='7에 2를 곱하면 14입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 44, 'total_tokens': 56, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1H6NJsbi7A3Pl0Wz8nBUL3BYPnN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--e28bd45d-e85f-4d44-9641-306145f2ded9-0', usage_metadata={'input_tokens': 44, 'output_tokens': 12, 'total_tokens': 56, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='마지막으로 계산했던 숫자가 뭐였지?', additional_kwargs={}, response_metadata={}, id='e73e53cb-83c1-437c-ad1d-c21214616e2b'),
#   AIMessage(content='마지막으로 계산했던 숫자는 14입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 75, 'total_tokens': 86, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1H9z4eMFtA9JON2Ewgd9E0ET5PD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--9af2ab5d-c6c5-4bd6-886f-ab013f9696fd-0', usage_metadata={'input_tokens': 75, 'output_tokens': 11, 'total_tokens': 86, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
temp = agent_with_memory.get_state(thread_1).values
temp['messages'][-1].content
# Out:
# '마지막으로 계산했던 숫자는 14입니다.'

# %% [markdown]
# * thread id 2 에 저장된 메모리 스냅샷

# %%
agent_with_memory.get_state(thread_2).values
# Out:
# {'messages': [HumanMessage(content='금리에 대한 정의를 알려줘.', additional_kwargs={}, response_metadata={}, id='0c9004a4-51f9-48b6-bb33-40b6226a8a45'),
#   AIMessage(content='금리(interest rate)는 일정 기간 동안 돈을 빌리거나 빌려줄 때 적용되는 비용 또는 수익의 비율을 말합니다. 쉽게 말해, 돈을 빌릴 때 지불해야 하는 대가 또는 돈을 예금할 때 받는 보상의 비율을 나타냅니다. 보통 연 단위 퍼센트(%)로 표현되며, 금리가 높을수록 돈을 빌리는 비용이 커지고, 예금자의 수익도 커집니다. 금리는 경제에 큰 영향을 미치며, 중앙은행의 정책금리, 대출금리, 예금금리 등 다양한 형태로 존재합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 141, 'prompt_tokens': 15, 'total_tokens': 156, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_c064fdde7c', 'id': 'chatcmpl-CP1H6BIq1zAMZ2NcKVfc7W54gJSC9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--e730191c-c60f-4add-a15a-876d6b31d134-0', usage_metadata={'input_tokens': 15, 'output_tokens': 141, 'total_tokens': 156, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# *  메모리 삭제
#     * 공식적으로 제공되지 않음.
#     * Thread id를 새로 시작하거나,
#     * memory 인스턴스를 다시 지정

# %% [markdown]
# ### (2) 최근 메시지 n개만 기억
#
# 기억할 메세지 개수 제한하기

# %% [markdown]
# * node 정의

# %%
def filter_messages(messages: list):
    # 최근 2개 메시지만 리턴하는 필터 함수 생성
    return messages[-2:]

def chatbot(state: State):
    messages = filter_messages(state["messages"])
    result = llm.invoke(messages)
    return {"messages": [result]}

# %% [markdown]
# * 그래프 정의

# %%
# initiate a graph
builder = StateGraph(State)

# add a node
builder.add_node("chatbot", chatbot)

# connect nodes
builder.add_edge(START, "chatbot")
builder.add_edge("chatbot", END)

# 체크포인터와 함께 그래프 컴파일
memory = MemorySaver()  # 메모리 기반 체크포인터 초기화
agent_with_memory = builder.compile(checkpointer=memory)

# %%
config_10 = {"configurable": {"thread_id": "10"}}
messages = [HumanMessage(content="3과 4를 더하라")]
messages = agent_with_memory.invoke({"messages": messages}, thread_1)
messages['messages'][-1].pretty_print()

messages = [HumanMessage(content="내 이름은 한기영이야.")]
messages = agent_with_memory.invoke({"messages": messages}, thread_1)
messages['messages'][-1].pretty_print()

messages = [HumanMessage(content="오늘 날씨 어때?")]
messages = agent_with_memory.invoke({"messages": messages}, thread_1)
messages['messages'][-1].pretty_print()

messages = [HumanMessage(content="아까 계산했던 값이 얼마?")]
messages = agent_with_memory.invoke({"messages": messages}, thread_1)
messages['messages'][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 3과 4를 더하면 7입니다.
# ================================== Ai Message ==================================
#
# 만나서 반갑습니다, 한기영님! 어떻게 도와드릴까요?
# ================================== Ai Message ==================================
#
# 죄송하지만 현재 사용자의 위치 정보를 알 수 없어 정확한 오늘 날씨를 알려드리기 어렵습니다. 어느 지역의 날씨를 알고 싶으신가요?
# ================================== Ai Message ==================================
#
# 아까 어떤 계산을 하셨는지 알려주실 수 있을까요? 그래야 제가 도움을 드릴 수 있을 것 같아요.

# %% [markdown]
# ### (3) [추가] 메시지 요약

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
memory = MemorySaver()

# %% [markdown]
# #### 1) State
# * MessagesState는 LangGraph가 기본 제공하는 메시지 기반 상태
# * 여기에 **summary**라는 새로운 필드를 추가
# * state 구조
#
#
#     {
#         "messages": [...],  # 전체 대화 기록
#         "summary": "지금까지 요약된 내용"
#     }

# %%
class State(MessagesState):
    summary: str

# %% [markdown]
# #### 2) 노드와 분기함수

# %% [markdown]
# * **대화 노드**
#
#     * 기존 메시지 리스트로 GPT를 호출해서 응답을 받고,
#     * 그 응답을 메시지 리스트에 **누적시킬 준비**를 해줌

# %%
def call_model(state: State):
    summary = state.get("summary", "")
    if summary:
        # 요약을 system prompt로 넣어 대화 맥락 유지
        system_message = f"이전 대화 요약: {summary}"
        messages = [SystemMessage(content=system_message)] + state["messages"]
    else:
        messages = state["messages"]

    response = llm.invoke(messages)
    return {"messages": [response]}

# %% [markdown]
# * **분기 조건**
#     * 메시지가 6개 초과하면 **summarize_conversation** 노드로 분기
#     * 그렇지 않으면 바로 **END**

# %%
def should_continue(state: State) -> Literal["summarize_conversation", END]:
    if len(state["messages"]) > 6:
        return "summarize_conversation"
    return END

# %% [markdown]
# * **요약 노드**
#     * 지금까지 대화 내용으로 요약 생성
#     * 메시지 너무 많아지지 않도록 앞쪽 메시지 삭제
#     * 요약은 state["summary"]에 저장됨 (누적 요약 느낌)

# %%
from langchain_core.messages import RemoveMessage

def summarize_conversation(state: State):
    summary = state.get("summary", "")   # 이전에 요약된게 있다면, 불러오고, 없으면 ""
    if summary:
        # 이전에 요약이 있다면:
        # 요약 내용을 GPT에게 보여주고
        # “여기에 새 메시지를 반영해서 요약을 이어서 해줘” 요청
        summary_message = (
            f"지금까지 요약된 내용 : {summary}\n\n"
            "여기에 새 메시지를 반영해서 요약을 이어서 해주세요. :" )
    else:
        # 이전 요약이 없다면 (처음 요약) → 대화 전체를 요약해달라고 지시
        summary_message = "대화 내용을 요약해주세요.:"

    # 기존 메시지 목록 끝에 요약 요청 프롬프트를 HumanMessage로 추가
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    # 전체 메시지 + 요약 요청을 GPT에게 전달해서 요약 결과 받기
    response = llm.invoke(messages)

    # 오래된 메시지를 제거 → 최신 2개만 유지
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# %% [markdown]
# #### 3) 그래프 정의

# %%
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node("summarize_conversation", summarize_conversation)

workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

memory = MemorySaver()
app = workflow.compile(checkpointer=memory)

# %%
# 외부 서버를 호출하는 동안 대기시간 초과로 오류가 날 수 있습니다.
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    pass

# %% [markdown]
# 1. 처음 6개 대화 → END
# 2. 7번째 입력 → summarize_conversation 실행
#     * 요약1 생성
#     * 오래된 메시지 삭제
# 3. 또 6개 쌓이면 → 요약2 생성
#     * 기존 요약 + 새 메시지로 “요약 이어 쓰기”
#     * 다시 삭제

# %% [markdown]
# #### 4) 대화 시작

# %% [markdown]
# * 출력 함수 생성
#
# | 부분 | 설명 |
# | ---- | ---- |
# | update | 그래프 노드 실행 후 변경된 상태 정보 |
# | messages | LLM 대화 메시지 리스트 |
# | summary | 누적된 요약 정보 (있으면 출력) |
# | pretty_print() | 메시지를 보기 좋게 출력하는 LangChain 메서드 |

# %%
def print_update(update):
    for k, v in update.items():
        for m in v["messages"]:
            m.pretty_print()
        if "summary" in v:
            print(v["summary"])

# %%
config = {"configurable": {"thread_id": "10"}}
input_message = HumanMessage(content="안녕? 내 이름은 핑크퐁이야")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)

input_message = HumanMessage(content="내이름이 뭐라고?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)

input_message = HumanMessage(content="나는 FC 바르셀로나를 좋아해!")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 핑크퐁이야
# ================================== Ai Message ==================================
#
# 안녕, 핑크퐁! 만나서 반가워요. 어떻게 도와줄까요?
# ================================ Human Message =================================
#
# 내이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 네 이름은 핑크퐁이라고 했어요! 맞나요?
# ================================ Human Message =================================
#
# 나는 FC 바르셀로나를 좋아해!
# ================================== Ai Message ==================================
#
# 오, FC 바르셀로나를 좋아하는구나! 멋진 팀이죠. 좋아하는 선수나 기억에 남는 경기가 있나요?

# %%
# 지금까지 요약이 이루어지지 않음
# 목록에 메시지가 6개뿐이기 때문입니다.

values = app.get_state(config).values
values
# Out:
# {'messages': [HumanMessage(content='안녕? 내 이름은 핑크퐁이야', additional_kwargs={}, response_metadata={}, id='ec456b4b-a639-4853-8c91-976622e2b3e7'),
#   AIMessage(content='안녕, 핑크퐁! 만나서 반가워요. 어떻게 도와줄까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 21, 'total_tokens': 44, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_c064fdde7c', 'id': 'chatcmpl-CP1HYdKrneOUEVchnOhEg8RoxHYoa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--d0a1383a-0691-44e6-b892-d185fc5f527e-0', usage_metadata={'input_tokens': 21, 'output_tokens': 23, 'total_tokens': 44, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='내이름이 뭐라고?', additional_kwargs={}, response_metadata={}, id='5a40e433-04f8-4e42-843b-54443b9e5325'),
#   AIMessage(content='네 이름은 핑크퐁이라고 했어요! 맞나요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 59, 'total_tokens': 75, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_c064fdde7c', 'id': 'chatcmpl-CP1HY9RyvLYTiB7FrMtg1M1Vf7r0F', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--c93be4dd-2e77-4e57-a65a-49f8f3354c6c-0', usage_metadata={'input_tokens': 59, 'output_tokens': 16, 'total_tokens': 75, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='나는 FC 바르셀로나를 좋아해!', additional_kwargs={}, response_metadata={}, id='8512a1e3-4feb-466d-b347-928880ed0b8e'),
#   AIMessage(content='오, FC 바르셀로나를 좋아하는구나! 멋진 팀이죠. 좋아하는 선수나 기억에 남는 경기가 있나요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 93, 'total_tokens': 126, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1HZVL8BjR2pZg9bs935mEPM1Rc3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2ca1dad7-3253-4e55-81ba-ca50f35717d4-0', usage_metadata={'input_tokens': 93, 'output_tokens': 33, 'total_tokens': 126, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# * 이제 한번 더 이야기하면, 과거 6개 메시지가 요약되고, 삭제 됩니다.

# %%
input_message = HumanMessage(content="나는 그들이 항상 이기는게 좋아.")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 나는 그들이 항상 이기는게 좋아.
# ================================== Ai Message ==================================
#
# 정말 멋진 마음가짐이에요! FC 바르셀로나가 계속 좋은 성적을 내면서 팬들에게 기쁨을 주길 함께 응원할게요. 혹시 좋아하는 경기나 순간이 있다면 얘기해 주세요!
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# 물론이죠! 지금까지 대화 내용을 요약해 드릴게요.
#
# - 당신의 이름은 핑크퐁입니다.
# - FC 바르셀로나를 좋아하십니다.
# - 그들이 항상 이기는 것을 좋아하십니다.
#
# 더 도와드릴 것이 있나요?

# %%
values = app.get_state(config).values
values
# Out:
# {'messages': [HumanMessage(content='나는 그들이 항상 이기는게 좋아.', additional_kwargs={}, response_metadata={}, id='2fa440db-2c58-4818-9682-f800ad07e321'),
#   AIMessage(content='정말 멋진 마음가짐이에요! FC 바르셀로나가 계속 좋은 성적을 내면서 팬들에게 기쁨을 주길 함께 응원할게요. 혹시 좋아하는 경기나 순간이 있다면 얘기해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 143, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1HaKpgTrfGpnLkOWZhDgNDyNxYa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--9253e205-f05a-453f-99ee-78f035e1cefe-0', usage_metadata={'input_tokens': 143, 'output_tokens': 55, 'total_tokens': 198, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  'summary': '물론이죠! 지금까지 대화 내용을 요약해 드릴게요.\n\n- 당신의 이름은 핑크퐁입니다.\n- FC 바르셀로나를 좋아하십니다.\n- 그들이 항상 이기는 것을 좋아하십니다.\n\n더 도와드릴 것이 있나요?'}

# %% [markdown]
# 이제 대화를 계속할 수 있습니다! 마지막 두 개의 메시지만 있지만 대화에서 앞서 언급한 내용에 대해 여전히 질문할 수 있습니다(요약했기 때문입니다)

# %%
input_message = HumanMessage(content="참, 내 이름이 뭐라고?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 참, 내 이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 당신의 이름은 핑크퐁이라고 하셨어요. 도움이 필요하시면 언제든 말씀해 주세요!

# %%
input_message = HumanMessage(content="내가 좋아하는 축구팀은?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 내가 좋아하는 축구팀은?
# ================================== Ai Message ==================================
#
# 당신이 좋아하는 축구팀은 FC 바르셀로나입니다! 언제든 팀에 대해 이야기하고 싶으면 알려주세요.

# %%
input_message = HumanMessage(content="우리팀과 경쟁하는 팀이 어디야?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 우리팀과 경쟁하는 팀이 어디야?
# ================================== Ai Message ==================================
#
# FC 바르셀로나와 경쟁하는 팀으로는 레알 마드리드가 가장 대표적입니다. 이 두 팀 간의 경기는 '엘 클라시코'라고 불리며, 축구 팬들에게 큰 관심을 받는 경기 중 하나입니다. 또한 아틀레티코 마드리드도 라리가에서 강력한 경쟁자 중 하나로 꼽힙니다. 궁금한 점 있으면 언제든 말씀해 주세요!
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# 물론입니다! 지금까지 대화 내용을 이어서 요약해 드릴게요.
#
# - 당신의 이름은 핑크퐁입니다.
# - FC 바르셀로나를 좋아하십니다.
# - 그들이 항상 이기는 것을 좋아하십니다.
# - FC 바르셀로나와 가장 경쟁하는 팀은 레알 마드리드이며, 이들 간의 경기는 '엘 클라시코'로 유명합니다.
# - 아틀레티코 마드리드도 강력한 라리가 경쟁자 중 하나입니다.
#
# 더 도와드릴 것이 있나요?

# %% [markdown]
# ## 5.실습

# %% [markdown]
# ### (1) 실습1
# * 최근 메시지 n개만 기억 : 기억할 메세지 개수 제한하기
#     * 기존 코드 수정하기
#     * 포함사항 : 시스템 메시지(역할) 지정하기(chatbot 함수에 추가)
#     * agent를 만들고 대화하면서 이전 메시지가 제외되는지 확인하기

# %% [markdown]
# * node 정의

# %%
def filter_messages(messages: list):
    # 최근 2개 메시지만 리턴하는 필터 함수 생성
    return messages[-2:]

def chatbot(state: State):
    recent = filter_messages(state["messages"])

    system = SystemMessage(content="너는 친절하고 간결한 도우미야. 질문에 짧고 명확하게 답해줘.")
    messages = [system] + recent

    result = llm.invoke(messages)
    return {"messages": [result]}

# %% [markdown]
# * 그래프 정의

# %%
# initiate a graph
builder = StateGraph(State)

# add a node
builder.add_node("chatbot", chatbot)

# connect nodes
builder.add_edge(START, "chatbot")
builder.add_edge("chatbot", END)

# 체크포인터와 함께 그래프 컴파일
memory = MemorySaver()  # 메모리 기반 체크포인터 초기화
agent_with_memory = builder.compile(checkpointer=memory)

# %%
thread_10 = {"configurable": {"thread_id": "10"}}
messages = [HumanMessage(content="3과 4를 더하라")]
messages = agent_with_memory.invoke({"messages": messages}, thread_10)
messages['messages'][-1].pretty_print()

messages = [HumanMessage(content="내 이름은 한기영이야.")]
messages = agent_with_memory.invoke({"messages": messages}, thread_10)
messages['messages'][-1].pretty_print()

messages = [HumanMessage(content="오늘 날씨 어때?")]
messages = agent_with_memory.invoke({"messages": messages}, thread_10)
messages['messages'][-1].pretty_print()

messages = [HumanMessage(content="아까 계산했던 값이 얼마?")]
messages = agent_with_memory.invoke({"messages": messages}, thread_10)
messages['messages'][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# 3과 4를 더하면 7입니다.
# ================================== Ai Message ==================================
#
# 안녕하세요, 한기영님! 어떻게 도와드릴까요?
# ================================== Ai Message ==================================
#
# 어디 지역 날씨를 알려드릴까요?
# ================================== Ai Message ==================================
#
# 죄송하지만, 이전 대화 내용을 기억하지 못해요. 어떤 계산 값을 말씀하시는지 다시 알려주실 수 있나요?

# %% [markdown]
# ### (2) [추가] 실습2
# 메시지 요약
#
# 위 실습1의 메모리를 요약 메모리로 변경해 봅시다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 1) State
#     * MessagesState는 LangGraph가 기본 제공하는 메시지 기반 상태
#     * 여기에 **summary**라는 새로운 필드를 추가

# %%
class State(MessagesState):
    summary: str

# %% [markdown]
# * 2) 노드와 분기함수

# %% [markdown]
# * **대화 노드**
#
#     * 기존 메시지 리스트로 GPT를 호출해서 응답을 받고,
#     * 그 응답을 메시지 리스트에 **누적시킬 준비**를 해줌

# %%
def call_model(state: State):
    summary = state.get("summary", "")
    if summary:
        # 요약을 system prompt로 넣어 대화 맥락 유지
        system_message = f'''너는 친절하고 간결한 도우미야. 질문에 짧고 명확하게 답해줘.
        이전 대화 요약: {summary}'''
        messages = [SystemMessage(content=system_message)] + state["messages"]
    else:
        messages = state["messages"]

    response = llm.invoke(messages)
    return {"messages": [response]}

# %% [markdown]
# * **분기 조건**
#     * 메시지가 6개 초과하면 **summarize_conversation** 노드로 분기
#     * 그렇지 않으면 바로 **END**

# %%
def should_continue(state: State) -> Literal["summarize_conversation", END]:
    if len(state["messages"]) > 6:
        return "summarize_conversation"
    return END

# %% [markdown]
# * **요약 노드**
#     * 지금까지 대화 내용으로 요약 생성
#     * 메시지 너무 많아지지 않도록 앞쪽 메시지 삭제
#     * 요약은 state["summary"]에 저장됨 (누적 요약 느낌)

# %%
from langchain_core.messages import RemoveMessage

def summarize_conversation(state: State):
    summary = state.get("summary", "")   # 이전에 요약된게 있다면, 불러오고, 없으면 ""
    if summary:
        # 이전에 요약이 있다면:
        # 요약 내용을 GPT에게 보여주고
        # “여기에 새 메시지를 반영해서 요약을 이어서 해줘” 요청
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
    else:
        # 이전 요약이 없다면 (처음 요약) → 대화 전체를 요약해달라고 지시
        summary_message = "Create a summary of the conversation above:"

    # 기존 메시지 목록 끝에 요약 요청 프롬프트를 HumanMessage로 추가
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    # 전체 메시지 + 요약 요청을 GPT에게 전달해서 요약 결과 받기
    response = llm.invoke(messages)

    # 오래된 메시지를 제거 → 최신 2개만 유지
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# %% [markdown]
# * 3) 그래프 정의

# %%
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node("summarize_conversation", summarize_conversation)

workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

memory = MemorySaver()
app = workflow.compile(checkpointer=memory)

# %%
# 외부 서버를 호출하는 동안 대기시간 초과로 오류가 날 수 있습니다.
try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    pass

# %% [markdown]
# * 4) 대화 시작

# %% [markdown]
# * 출력 함수 생성
#
# | 부분 | 설명 |
# | ---- | ---- |
# | update | 그래프 노드 실행 후 변경된 상태 정보 |
# | messages | LLM 대화 메시지 리스트 |
# | summary | 누적된 요약 정보 (있으면 출력) |
# | pretty_print() | 메시지를 보기 좋게 출력하는 LangChain 메서드 |

# %%
def print_update(update):
    for k, v in update.items():
        for m in v["messages"]:
            m.pretty_print()
        if "summary" in v:
            print(v["summary"])

# %%
config = {"configurable": {"thread_id": "20"}}
input_message = HumanMessage(content="안녕? 내 이름은 핑크퐁이야")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)

input_message = HumanMessage(content="내이름이 뭐라고?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)

input_message = HumanMessage(content="나는 FC 바르셀로나를 좋아해!")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 안녕? 내 이름은 핑크퐁이야
# ================================== Ai Message ==================================
#
# 안녕, 핑크퐁! 만나서 반가워요. 어떻게 도와줄까요?
# ================================ Human Message =================================
#
# 내이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 당신 이름은 핑크퐁이라고 하셨어요!
# ================================ Human Message =================================
#
# 나는 FC 바르셀로나를 좋아해!
# ================================== Ai Message ==================================
#
# 와, FC 바르셀로나를 좋아하다니 멋지네요! 어떤 선수를 특히 좋아하세요? 아니면 바르셀로나의 어떤 점이 마음에 드나요?

# %% [markdown]
# * 이제 한번 더 이야기하면, 과거 6개 메시지가 요약되고, 삭제 됩니다.

# %%
input_message = HumanMessage(content="나는 그들이 항상 이기는게 좋아.")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 나는 그들이 항상 이기는게 좋아.
# ================================== Ai Message ==================================
#
# 정말 멋진 이유네요! FC 바르셀로나가 강팀이라서 항상 좋은 경기력을 보여주니까 팬으로서 정말 자랑스러울 거예요. 앞으로도 그들의 멋진 승리를 많이 볼 수 있길 바랄게요! 혹시 바르셀로나와 관련해서 더 이야기하고 싶은 게 있나요?
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# The user introduced themselves as "핑크퐁" and shared that they like FC Barcelona, especially appreciating their consistent winning. The assistant greeted the user, confirmed their name, engaged with their interest in FC Barcelona by asking about favorite players or aspects, and responded positively to the user’s appreciation of the team's success. The conversation was friendly and supportive.

# %% [markdown]
# 이제 대화를 계속할 수 있습니다! 마지막 두 개의 메시지만 있지만 대화에서 앞서 언급한 내용에 대해 여전히 질문할 수 있습니다(요약했기 때문입니다)

# %%
input_message = HumanMessage(content="참, 내 이름이 뭐라고?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 참, 내 이름이 뭐라고?
# ================================== Ai Message ==================================
#
# 당신의 이름은 핑크퐁입니다.

# %%
input_message = HumanMessage(content="내가 좋아하는 축구팀은?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 내가 좋아하는 축구팀은?
# ================================== Ai Message ==================================
#
# 당신이 좋아하는 축구팀은 FC 바르셀로나입니다.

# %%
input_message = HumanMessage(content="우리팀과 경쟁하는 팀이 어디야?")
input_message.pretty_print()
for event in app.stream({"messages": [input_message]}, config, stream_mode="updates"):
    print_update(event)
# Out:
# ================================ Human Message =================================
#
# 우리팀과 경쟁하는 팀이 어디야?
# ================================== Ai Message ==================================
#
# FC 바르셀로나의 주요 경쟁팀으로는 레알 마드리드가 있어요. 이 두 팀의 경기는 ‘엘 클라시코’라고 불리며 아주 치열하고 인기 있답니다.
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# ================================ Remove Message ================================
#
#
# After confirming the user's name as "핑크퐁" and acknowledging their fondness for FC 바르셀로나, the assistant answered the user's question about their favorite football team, affirming it is FC 바르셀로나. When the user inquired about the teams that compete against their favorite team, the assistant identified 레알 마드리드 as FC 바르셀로나’s main rival, highlighting their famous matches known as ‘엘 클라시코.’ Throughout the conversation, the assistant maintained a friendly and engaging tone, encouraging further discussion about the user's interests.

# %% [markdown]
# ## 6.체크포인트 저장소(Checkpoint Store)
#
# SQLite DB
#
# **구성**
# - checkpoints.sqlite
#     - 메인 데이터베이스 파일
#     - 모든 데이터의 기본 저장소
# - checkpoints.sqlite-wal
#     - 쓰기 로그(Write-Ahead Log)
#     - 최신 변경사항이 일시적으로 저장됨
# - checkpoints.sqlite-shm
#     - 공유 메모리 파일 (Shared Memory)

# %%
# !pip install langgraph-checkpoint-sqlite -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 5.0 MB/s eta 0:00:00

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

# %% [markdown]
# ### (1) DB 생성 및 연결

# %%
# check_same_thread=False - 여러 스레드에서 같은 연결 객체를 공유할 수 있도록 허용
# LangGraph나 LangChain은 비동기 처리 또는 멀티 스레드 실행을 사용하는 경우가 많음

sqlite3_conn = sqlite3.connect('checkpoints.sqlite',check_same_thread=False)
sqlite3_memory_checkpoint = SqliteSaver(sqlite3_conn)

# %% [markdown]
# ### (2) 메모리 지정

# %%
graph = builder.compile(checkpointer=sqlite3_memory_checkpoint)

# %% [markdown]
# ### (3) 대화

# %%
graph.invoke(
    {"messages": [HumanMessage("안녕?")]},
    config={"configurable": {"thread_id": 1}}
)
# Out:
# {'messages': [HumanMessage(content='안녕?', additional_kwargs={}, response_metadata={}, id='d28ab7b6-8ea4-4633-823a-6499cae75952'),
#   AIMessage(content='안녕! 무엇을 도와줄까?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 39, 'total_tokens': 49, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1I2nUFnxcJUGnoA5U5GvILMIXBU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--b5d8867b-f357-4e1b-aba9-6bb785c69194-0', usage_metadata={'input_tokens': 39, 'output_tokens': 10, 'total_tokens': 49, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
graph.invoke(
    {"messages": [HumanMessage("내이름은 한기영")]},
    config={"configurable": {"thread_id": 1}}
)
# Out:
# {'messages': [HumanMessage(content='안녕?', additional_kwargs={}, response_metadata={}, id='d28ab7b6-8ea4-4633-823a-6499cae75952'),
#   AIMessage(content='안녕! 무엇을 도와줄까?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 39, 'total_tokens': 49, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1I2nUFnxcJUGnoA5U5GvILMIXBU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--b5d8867b-f357-4e1b-aba9-6bb785c69194-0', usage_metadata={'input_tokens': 39, 'output_tokens': 10, 'total_tokens': 49, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   HumanMessage(content='내이름은 한기영', additional_kwargs={}, response_metadata={}, id='8210685e-8526-4bbd-bb80-2fc592cc28e6'),
#   AIMessage(content='반가워요, 한기영님! 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 57, 'total_tokens': 75, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_95d112f245', 'id': 'chatcmpl-CP1I2GzRf3cfBm4P5SvCh3wsq9g3U', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--dfa43a1e-eb4e-4b0c-97d8-fad6cd7f5a7f-0', usage_metadata={'input_tokens': 57, 'output_tokens': 18, 'total_tokens': 75, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
